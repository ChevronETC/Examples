# %% [markdown]
# # Single trace FWI sensitivity kernel
# Here we generate a single source, single receiver "banana donut" sensitivity kernel for full waveform inversion in constant velocity models. The workflow:
# 1. generate forward modeled data in true model
# 1. generate forward modeled data in slow model
# 1. backproject the residual (d_true - d_slow) ... the fwi gradient

# %%
using PyPlot, Jets, WaveFD, JetPackWaveFD, Random

# %% [markdown]
# ## Generate the true and starting models

# %%
nz,nx = 400,600
dz,dx = 20.0,20.0
@show nz,nx;
@show dz,dx
v1 = 2000 .* ones(Float32,nz,nx)
v2 = 1950 .* ones(Float32,nz,nx);
# Out:
# (nz, nx) = (400, 600)
# (dz, dx) = (20.0, 20.0)

# %%
figure(figsize=(10,5))
vmin,vmax = 1900,2050
@show extrema(v1)
subplot(121);imshow(v1,aspect="auto");title("True model");clim(vmin,vmax);
colorbar(orientation="horizontal")
subplot(122);imshow(v2,aspect="auto");title("Slow model");clim(vmin,vmax)
colorbar(orientation="horizontal");
# Out:
# Figure(PyObject <Figure size 1000x500 with 4 Axes>)
# extrema(v1) = (2000.0f0, 2000.0f0)

# %% [markdown]
# ## Note on scratch space for temporary files
# When dealing with serialized nonlinear wavefields as in this example, we need to specify the location where scratch files will be written.
#
# You may need to change this to point to a temporary directory available on your system.

# %%
scratch = "/mnt/scratch"
@assert isdir(scratch)

# %%
F = JopNlProp2DAcoIsoDenQ_DEO2_FDTD(;
    b = ones(Float32,size(v1)),
    nthreads = Sys.CPU_THREADS,
    isinterior = true,
    nsponge = 80,
    ntrec = 2001,
    dtrec = 0.004,
    dtmod = 0.002,
    dz = dz,
    dx = dx,
    wavelet = WaveletCausalRicker(f=2.5),
    sx = dx * (1),
    sz = dz * div(nz,2),
    rx = [dx * (nx-1)],
    rz = [dz * div(nz,2)],
    srcfieldfile = joinpath(scratch, "field-$(randstring()).bin"),
    reportinterval=1000);

# %% [markdown]
# ## Forward modeling in true and slow models

# %%
d1 = F*v1;
d2 = F*v2;
# Out:
# ┌ Info: nonlinear forward on cbox-wask-HB60rs, srcfieldfile=/mnt/scratch/field-icMhEWU6.bin
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:387
# ┌ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step     1 of  4001 ;    0.00 MCells/s (IO= 0.00%, EX= 0.00%) -- rms d,p; 0.0000e+00 0.0000e+00
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:703
# ┌ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  1000 of  4001 ;  155.20 MCells/s (IO=51.79%, EX=30.44%) -- rms d,p; 0.0000e+00 1.6118e+00
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:703
# ┌ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  2000 of  4001 ;  170.00 MCells/s (IO=52.75%, EX=29.33%) -- rms d,p; 0.0000e+00 7.6385e-01
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:703
# ┌ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  3000 of  4001 ;  170.77 MCells/s (IO=52.10%, EX=28.75%) -- rms d,p; 1.1183e-05 4.3638e-01
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:703
# ┌ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  4000 of  4001 ;  174.67 MCells/s (IO=52.61%, EX=28.59%) -- rms d,p; 4.1190e-01 4.8302e-02
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:703
# ┌ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  4001 of  4001 ;  174.70 MCells/s (IO=52.60%, EX=28.59%) -- rms d,p; 4.1190e-01 4.8254e-02
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:703
# ┌ Info: nonlinear forward on cbox-wask-HB60rs, srcfieldfile=/mnt/scratch/field-icMhEWU6.bin
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:387
# ┌ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step     1 of  4001 ;    0.00 MCells/s (IO= 0.00%, EX= 0.00%) -- rms d,p; 0.0000e+00 0.0000e+00
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:703
# ┌ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  1000 of  4001 ;  185.48 MCells/s (IO=53.94%, EX=27.70%) -- rms d,p; 0.0000e+00 1.5720e+00
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:703
# ┌ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  2000 of  4001 ;  187.02 MCells/s (IO=54.31%, EX=27.69%) -- rms d,p; 0.0000e+00 7.5565e-01
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:703
# ┌ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  3000 of  4001 ;  187.32 MCells/s (IO=54.39%, EX=27.68%) -- rms d,p; 1.9864e-09 4.2997e-01
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:703
# ┌ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  4000 of  4001 ;  186.46 MCells/s (IO=54.40%, EX=27.67%) -- rms d,p; 3.9608e-01 5.0291e-02
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:703
# ┌ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  4001 of  4001 ;  186.48 MCells/s (IO=54.39%, EX=27.67%) -- rms d,p; 3.9608e-01 5.0197e-02
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:703

# %% [markdown]
# ## Compute the residual
# With $v_1$ the true model, and $v_2$ the background model, the FWI objective function is written as:
#
# $$
# \bigl\| f(v_2) - f(v_1) \bigr\|
# $$
#
# The residual is then:
#
# $$
# r = d_2 - d_1
# $$

# %%
r = d2 .- d1
@show extrema(d1)
@show extrema(d2)
@show extrema(r)
# Out:
# extrema(d1) = (-1.9544239f0, 3.1496422f0)
# extrema(d2) = (-1.8844594f0, 3.0342908f0)
# extrema(r) = (-5.0061893f0, 3.5186372f0)
# (-5.0061893f0, 3.5186372f0)

# %% [markdown]
# ## Plot the generated traces

# %%
dmax = maximum(abs, d1)
figure(figsize=(9,6)); clf()
t = 0.004 .* [0:1:2000;]
plot(t,d1[:], label="True model", "blue", linewidth=1)
plot(t,d2[:], label="Slow model", "black", linewidth=1)
plot(t,r[:], label="Residual", "red", linewidth=1)
xlim(5,8)
legend()
nothing
# Out:
# Figure(PyObject <Figure size 900x600 with 1 Axes>)

# %% [markdown]
# ## Backproject the residual with the Jacobian adjoint

# %%
J = jacobian!(F, v2)
dv = J' * r;
# Out:
# ┌ Info: linear adjoint on cbox-wask-HB60rs, srcfieldfile=/mnt/scratch/field-icMhEWU6.bin
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:626
# ┌ Info: PropLn2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  4001 ;    0.00 MCells/s (IO= 0.00%, EX= 0.00%, IM= 0.00%) -- rms d,p; 3.3940e-01 0.0000e+00
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:693
# ┌ Info: PropLn2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     2 of  4001 ;    0.00 MCells/s (IO= 5.05%, EX= 3.42%, IM= 1.99%) -- rms d,p; 3.3940e-01 0.0000e+00
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:693
# ┌ Info: PropLn2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step  1002 of  4001 ;  155.11 MCells/s (IO=67.29%, EX=15.33%, IM= 3.92%) -- rms d,p; 3.3940e-01 6.1487e+00
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:693
# ┌ Info: PropLn2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step  2002 of  4001 ;  159.90 MCells/s (IO=70.04%, EX=12.31%, IM= 4.41%) -- rms d,p; 3.3940e-01 3.4144e+00
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:693
# ┌ Info: PropLn2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step  3002 of  4001 ;  162.01 MCells/s (IO=71.21%, EX=11.07%, IM= 4.57%) -- rms d,p; 3.3940e-01 1.5734e+00
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:693
# ┌ Info: PropLn2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step  4001 of  4001 ;  162.57 MCells/s (IO=71.64%, EX=10.45%, IM= 4.60%) -- rms d,p; 3.3940e-01 8.3986e-01
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:693

# %% [markdown]
# ## Plot the sensitivity kernel
# Note this is the FWI gradient, and we would improve the velocity model by `-1 * gradient`. The blue central part of the sensitivity kernel therefore has the correct polarity, indicating we need to make the slow velocity model faster.

# %%
figure(figsize=(10,5))
dmax = maximum(abs,dv)
imshow(dv,aspect="auto", cmap="seismic", clim=0.25 .* [-dmax,dmax]);
title("Single Trace Sensitivity Kernel")
colorbar();
# Out:
# Figure(PyObject <Figure size 1000x500 with 2 Axes>)
