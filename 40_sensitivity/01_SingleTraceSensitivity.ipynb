# %% [markdown]
# # Single trace FWI sensitivity kernel
# Here we generate a single source, single receiver "banana donut" sensitivity kernel for full waveform inversion in constant velocity models. The workflow:
# 1. generate forward modeled data in true model
# 1. generate forward modeled data in slow model
# 1. backproject the residual (d_true - d_slow) ... the fwi gradient

# %%
using PyPlot, Jets, WaveFD, JetPackWaveFD, Random

# %% [markdown]
# ## Generate the true and starting models
#
# Even though this is a 2D example, the model passed to the nonlinear operator below is 3D, with size [nz,nx,1] for the velocity only case. In the case of variable density acoustics, the model would be of size [nz,nx,2].

# %%
nz,nx = 400,600
dz,dx = 20.0,20.0
@show nz,nx;
@show dz,dx
m1 = 2000 .* ones(Float32,nz,nx,1)
m2 = 1950 .* ones(Float32,nz,nx,2);
# Out:
# (nz, nx) = (400, 600)
# (dz, dx) = (20.0, 20.0)

# %%
figure(figsize=(10,5))
vmin,vmax = 1900,2050
@show extrema(m1)
subplot(121);imshow(m1[:,:,1],aspect="auto");title("True model");clim(vmin,vmax);
colorbar(orientation="horizontal")
subplot(122);imshow(m2[:,:,1],aspect="auto");title("Slow model");clim(vmin,vmax)
colorbar(orientation="horizontal");
# Out:
# Figure(PyObject <Figure size 1000x500 with 4 Axes>)
# extrema(m1) = (2000.0f0, 2000.0f0)

# %% [markdown]
# ## Note on scratch space for temporary files
# When dealing with serialized nonlinear wavefields as in this example, we need to specify the location where scratch files will be written.
#
# You may need to change this to point to a temporary directory available on your system.

# %%
scratch = "/mnt/scratch"
@assert isdir(scratch)

# %%
F = JopNlProp2DAcoIsoDenQ_DEO2_FDTD(;
    b = ones(Float32,nz,nx),
    nthreads = Sys.CPU_THREADS,
    isinterior = true,
    nsponge = 80,
    ntrec = 2001,
    dtrec = 0.004,
    dtmod = 0.002,
    dz = dz,
    dx = dx,
    wavelet = WaveletCausalRicker(f=2.5),
    sx = dx * (1),
    sz = dz * div(nz,2),
    rx = [dx * (nx-1)],
    rz = [dz * div(nz,2)],
    srcfieldfile = joinpath(scratch, "field-$(randstring()).bin"),
    reportinterval=1000);

# %% [markdown]
# ## Forward modeling in true and slow models

# %%
d1 = F*m1;
d2 = F*m2;
# Out:
# ┌ Info: nonlinear forward on cbox-HC44rs2, srcfieldfile=/mnt/scratch/field-sOHeWYRo.bin
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:472
# ┌ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  1000 of  4001  152.52 MCells/s (IO=44.18, EX=34.53, PR=18.61) -- rms d,p; 0.0000e+00 1.6118e+00
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:863
# ┌ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  2000 of  4001  165.62 MCells/s (IO=48.17, EX=26.45, PR=16.65) -- rms d,p; 0.0000e+00 7.6385e-01
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:863
# ┌ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  3000 of  4001  174.81 MCells/s (IO=50.88, EX=23.77, PR=18.53) -- rms d,p; 1.1183e-05 4.3638e-01
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:863
# ┌ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  4000 of  4001  177.51 MCells/s (IO=51.62, EX=21.94, PR=20.68) -- rms d,p; 4.1190e-01 4.8301e-02
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:863
# ┌ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  4001 of  4001  177.53 MCells/s (IO=51.62, EX=21.94, PR=20.68) -- rms d,p; 4.1190e-01 4.8253e-02
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:863
# ┌ Info: nonlinear forward on cbox-HC44rs2, srcfieldfile=/mnt/scratch/field-sOHeWYRo.bin
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:472
# ┌ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  1000 of  4001  204.22 MCells/s (IO=59.45, EX=18.82, PR=20.22) -- rms d,p; 0.0000e+00 1.5720e+00
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:863
# ┌ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  2000 of  4001  208.78 MCells/s (IO=60.64, EX=18.65, PR=19.37) -- rms d,p; 0.0000e+00 7.5565e-01
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:863
# ┌ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  3000 of  4001  206.37 MCells/s (IO=59.91, EX=18.55, PR=20.04) -- rms d,p; 1.9865e-09 4.2997e-01
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:863
# ┌ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  4000 of  4001  201.71 MCells/s (IO=58.53, EX=18.06, PR=21.69) -- rms d,p; 3.9608e-01 5.0290e-02
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:863
# ┌ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  4001 of  4001  201.73 MCells/s (IO=58.52, EX=18.06, PR=21.69) -- rms d,p; 3.9608e-01 5.0197e-02
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:863

# %% [markdown]
# ## Compute the residual
# With $v_1$ the true model, and $v_2$ the background model, the FWI objective function is written as:
#
# $$
# \bigl\| f(v_2) - f(v_1) \bigr\|
# $$
#
# The residual is then:
#
# $$
# r = d_2 - d_1
# $$

# %%
r = d2 .- d1
@show extrema(d1)
@show extrema(d2)
@show extrema(r)
# Out:
# extrema(d1) = (-1.9544184f0, 3.149633f0)
# extrema(d2) = (-1.8844676f0, 3.0342908f0)
# extrema(r) = (-5.0061855f0, 3.5186477f0)
# (-5.0061855f0, 3.5186477f0)

# %% [markdown]
# ## Plot the generated traces

# %%
dmax = maximum(abs, d1)
figure(figsize=(9,6)); clf()
t = 0.004 .* [0:1:2000;]
plot(t,d1[:], label="True model", "blue", linewidth=1)
plot(t,d2[:], label="Slow model", "black", linewidth=1)
plot(t,r[:], label="Residual", "red", linewidth=1)
xlim(5,8)
legend()
nothing
# Out:
# Figure(PyObject <Figure size 900x600 with 1 Axes>)

# %% [markdown]
# ## Backproject the residual with the Jacobian adjoint

# %%
J = jacobian!(F, m2)
dv = J' * r;
# Out:
# ┌ Info: linear adjoint on cbox-HC44rs2, srcfieldfile=/mnt/scratch/field-sOHeWYRo.bin
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:760
# ┌ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  4001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 3.3940e-01 0.0000e+00
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:850
# ┌ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     2 of  4001    0.00 MCells/s (IO=45.53, EX= 8.90, IM=13.76, PR=17.30) -- rms d,p; 3.3940e-01 0.0000e+00
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:850
# ┌ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step  1002 of  4001  341.88 MCells/s (IO=40.81, EX=19.33, IM= 4.38, PR=35.38) -- rms d,p; 3.3940e-01 6.1486e+00
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:850
# ┌ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step  2002 of  4001  402.36 MCells/s (IO=48.12, EX=20.46, IM= 3.88, PR=27.44) -- rms d,p; 3.3940e-01 3.4144e+00
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:850
# ┌ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step  3002 of  4001  413.76 MCells/s (IO=49.52, EX=20.63, IM= 3.79, PR=25.95) -- rms d,p; 3.3940e-01 1.5734e+00
# └ @ JetPackWaveFD /home/cvx/.julia/dev/JetPackWaveFD/src/jop_prop2DAcoIsoDenQ_DEO2_FDTD.jl:850

# %% [markdown]
# ## Plot the sensitivity kernel
# Note this is the FWI gradient, and we would improve the velocity model by `-1 * gradient`. The blue central part of the sensitivity kernel therefore has the correct polarity, indicating we need to make the slow velocity model faster.

# %%
figure(figsize=(10,5))
dmax = maximum(abs,dv)
imshow(dv[:,:,1],aspect="auto", cmap="seismic", clim=0.25 .* [-dmax,dmax]);
title("Single Trace Sensitivity Kernel")
colorbar();
# Out:
# Figure(PyObject <Figure size 1000x500 with 2 Axes>)
